# %% [markdown]
# # Lab 3.2 - Student Notebook
#
# Hecho por: Santiago Chacon

# %% [markdown]
# ## Overview
#
# This lab is a continuation of the guided labs in Module 3.
#
# ## Introducing the business scenario
#
# You work for a healthcare provider, and want to improve the detection of abnormalities in orthopedic patients.
#
# You are tasked with solving this problem by using machine learning (ML). You have access to a dataset that contains six biomechanical features and a target of *normal* or *abnormal*. You can use this dataset to train an ML model to predict if a patient will have an abnormality.
#
# ## About this dataset
# This biomedical dataset was built by Dr. Henrique da Mota during a medical residence period in the Group of Applied Research in Orthopaedics (GARO) of the Centre Médico-Chirurgical de Réadaptation des Massues, Lyon, France. The data has been organized in two different, but related, classification tasks.
#
# The first task consists in classifying patients as belonging to one of three categories:
#
# - *Normal* (100 patients)
# - *Disk Hernia* (60 patients)
# - *Spondylolisthesis* (150 patients)
#
# For the second task, the categories *Disk Hernia* and *Spondylolisthesis* were merged into a single category that is labeled as *abnormal*. Thus, the second task consists in classifying patients as belonging to one of two categories: *Normal* (100 patients) or *Abnormal* (210 patients).
#
#
# ## Attribute information
#
# Each patient is represented in the dataset by six biomechanical attributes that are derived from the shape and orientation of the pelvis and lumbar spine (in this order):
#
# - Pelvic incidence
# - Pelvic tilt
# - Lumbar lordosis angle
# - Sacral slope
# - Pelvic radius
# - Grade of spondylolisthesis
#
# The following convention is used for the class labels:
# - DH (Disk Hernia)
# - Spondylolisthesis (SL)
# - Normal (NO)
# - Abnormal (AB)
#
#
# For more information about this dataset, see the [Vertebral Column dataset webpage](http://archive.ics.uci.edu/ml/datasets/Vertebral+Column).
#
# ## Dataset attributions
# This dataset was obtained from:
# Dua, D. and Graff, C. (2019). UCI Machine Learning Repository (http://archive.ics.uci.edu/ml). Irvine, CA: University of California, School of Information and Computer Science.

# %% [markdown]
# # Lab setup
# Because this solution is split across several labs in this module, you must run the following cells so that you can load the data:

# %% [markdown]
# ## Importing the data

# %%
# !pip install scipy
# Out:
# Collecting scipy
#   Using cached scipy-1.15.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Requirement already satisfied: numpy<2.5,>=1.23.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from scipy) (2.2.6)
# Using cached scipy-1.15.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (37.7 MB)
# Installing collected packages: scipy
# Successfully installed scipy-1.15.3

# %%
import warnings, requests, zipfile, io
warnings.simplefilter('ignore')
import pandas as pd
from scipy.io import arff

# %%
f_zip = 'http://archive.ics.uci.edu/ml/machine-learning-databases/00212/vertebral_column_data.zip'
r = requests.get(f_zip, stream=True)
Vertebral_zip = zipfile.ZipFile(io.BytesIO(r.content))
Vertebral_zip.extractall()

# %%
data = arff.loadarff('column_2C_weka.arff')
df = pd.DataFrame(data[0])

# %% [markdown]
# # Step 1: Exploring the data
# You will start by looking at the data in the dataset.
#
# To get the most out of this lab, carefully read the instructions and code before you run the cells. Take time to experiment!

# %% [markdown]
# First, you will use **shape** to examine the number of rows and columns

# %%
df.shape
# Out:
# (310, 7)

# %% [markdown]
# You will now get a list of the columns.

# %%
df.columns
# Out:
# Index(['pelvic_incidence', 'pelvic_tilt', 'lumbar_lordosis_angle',
#        'sacral_slope', 'pelvic_radius', 'degree_spondylolisthesis', 'class'],
#       dtype='object')

# %% [markdown]
# You can see the six biomechanical features, and the target column is named *class*.
#
# What column types do you have?

# %%
df.dtypes
# Out:
# pelvic_incidence            float64
# pelvic_tilt                 float64
# lumbar_lordosis_angle       float64
# sacral_slope                float64
# pelvic_radius               float64
# degree_spondylolisthesis    float64
# class                        object
# dtype: object

# %% [markdown]
# You have six floats for the biomechanical features, but the target is a class.
#
# To look at the statistics for the first column, you can use the **describe** function.

# %%
df['pelvic_incidence'].describe()
# Out:
# count    310.000000
# mean      60.496653
# std       17.236520
# min       26.147921
# 25%       46.430294
# 50%       58.691038
# 75%       72.877696
# max      129.834041
# Name: pelvic_incidence, dtype: float64

# %% [markdown]
# **Challenge Task:** Try updating the code in the previous cell to view the statistics of other features. Which features have outliers that you might want to examine?

# %% [markdown]
# Because this dataset only has six features, you can display the statistics of each feature by running **describe** on the entire DataFrame.

# %%
df.describe()
# Out:
#        pelvic_incidence  pelvic_tilt  lumbar_lordosis_angle  sacral_slope  \
# count        310.000000   310.000000             310.000000    310.000000
# mean          60.496653    17.542822              51.930930     42.953831
# std           17.236520    10.008330              18.554064     13.423102
# min           26.147921    -6.554948              14.000000     13.366931
# 25%           46.430294    10.667069              37.000000     33.347122
# 50%           58.691038    16.357689              49.562398     42.404912
# 75%           72.877696    22.120395              63.000000     52.695888
# max          129.834041    49.431864             125.742385    121.429566
#
#        pelvic_radius  degree_spondylolisthesis
# count     310.000000                310.000000
# mean      117.920655                 26.296694
# std        13.317377                 37.559027
# min        70.082575                -11.058179
# 25%       110.709196                  1.603727
# 50%       118.268178                 11.767934
# 75%       125.467674                 41.287352
# max       163.071041                418.543082

# %% [markdown]
# **Question:** Are there any features that aren't well-distributed? Are there any features with outliers that you want to look at? Does it look like there might be any correlations between features?

# %% [markdown]
# # 1) Hay alguna categoria la cual no este bien distribuida?
#
# Si, el "degree_spondylolisthesis" tiene demasiados problemas, la media y mediana (26.296 y 11.767 respectivamente) estan bastante desproporcionados, lo que indica que los numeros tienen una inclinacion a los numeros mayores, pero realmente esto es solo una pista del siguiente dato, el 75% se encuentra en 41.2.87 mientras el maximo es un numero gigantesco, lo cual indica que el 25% o menos de los valores son valores completamente alejaos del resto con cifras gigantescas.
#
# # 2) Hay valores atipicos?
#
# Si, podriamos usar el mismo ejemplo de degree_spondylolisthesis que es el valor atipico mas exagerado, pero para mencionar otros casos, tambien tenemos el de "pelvic_incidence" que tiene 129.834 de valor maximo cuando el 75% es de 72.877, "lumbar_lordosis_angle" con un valor maximo de 125.742 y uno de 75% de 63 y por ultimo, "sacral_slope" con 121.429 de maximo y 52.695 de 75%.
#
# # 3) Hay alguna correlacion entre las categorias?
#
# Es complicado decir con la cantidad de datos que poseo, mas a plena vista diria que "lumbar_lordosis_angle" y "pelvic_radius", sus datos parecen tener una relacion de una dorma u otra pues son demasiado parecidos el uno al otro.

# %% [markdown]
# It's not always easy to make observations when you look only at numbers, so you will now plot these values.

# %%
# !pip install matplotlib
# Out:
# Collecting matplotlib
#   Using cached matplotlib-3.10.9-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (52 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Using cached contourpy-1.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.65.0-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (125 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Using cached kiwisolver-1.5.1-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (5.2 kB)
# Requirement already satisfied: numpy>=1.23 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from matplotlib) (2.2.6)
# Requirement already satisfied: packaging>=20.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from matplotlib) (24.2)
# Collecting pillow>=8 (from matplotlib)
#   Using cached pillow-12.3.0-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (9.1 kB)
# Collecting pyparsing>=3 (from matplotlib)
#   Using cached pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Using cached matplotlib-3.10.9-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (8.8 MB)
# Using cached contourpy-1.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (325 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.65.0-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (5.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 100.8 MB/s  0:00:00
# Using cached kiwisolver-1.5.1-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.6 MB)
# Using cached pillow-12.3.0-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (6.9 MB)
# Using cached pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/7 [matplotlib]7 [matplotlib]
# Successfully installed contourpy-1.3.2 cycler-0.12.1 fonttools-4.65.0 kiwisolver-1.5.1 matplotlib-3.10.9 pillow-12.3.0 pyparsing-3.3.2

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
df.plot()
# Out:
# <Axes: >

# %% [markdown]
# You will now plot the distribution of the values for each feature by using a *density or kernel density estimate (KDE) plot*.

# %%
df.plot(kind='density',subplots=True,layout=(4,2),figsize=(12,12),sharex=False)
plt.show()

# %% [markdown]
# Do any of the visualizations stand out?
#
# ### Investigating degree_spondylolisthesis
# You will now investigate **degree_spondylolisthesis**:

# %% [markdown]
# Start with the *density plot*, which if you recall, shows the *distribution of the values*.

# %%
df['degree_spondylolisthesis'].plot.density()
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# A density plot smooths out the curve. It looks like there might be an increase around **400**. Visualize the data with a *histogram*.

# %%
df['degree_spondylolisthesis'].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# By using a *box plot*, you can see if there any outliers.

# %%
df['degree_spondylolisthesis'].plot.box()
# Out:
# <Axes: >

# %% [markdown]
# You can see a small increase around **400**. Sometimes, outliers like this can throw off training models. The only way to find out would be to test the model both with and without the outliers, and compare the models' scores. However, this is a task for a later lab.

# %% [markdown]
# You can see from the box plot that there seems to be a cluster above what *looks like* the maximum. Is there a correlation between those data points and the target?

# %% [markdown]
# Before you can look for a correlation, you will examine the target more.
#
# ### Analyzing the target
#
# First, what kind of distribution do you have?

# %%
df['class'].value_counts()
# Out:
# class
# b'Abnormal'    210
# b'Normal'      100
# Name: count, dtype: int64

# %% [markdown]
# It loks like you have about 1/3 *Normal* and 2/3 *Abnormal*. This result should be fine, but if you could get more data, you would want to try and balance the numbers more.

# %% [markdown]
# The class values aren't going to work for your ML model, so you will convert this column to a numeric value. You can use a *mapper* for this task.

# %%
class_mapper = {b'Abnormal':1,b'Normal':0}
df['class']=df['class'].replace(class_mapper)

# %% [markdown]
# Now, you can plot the *degree_spondylolisthesis* against the target.

# %%
df.plot.scatter(y='degree_spondylolisthesis',x='class')
# Out:
# <Axes: xlabel='class', ylabel='degree_spondylolisthesis'>

# %% [markdown]
# What do you see?
#
# Though there appears to be a link between the high values and the abnormalities, there are also many values that are in the same range. So, there could be a correlation, but it's worth taking a closer look at the data.
#
# **Challenge Task:** By using the previous cells, determine how the values of other features correspond against the target.

# %%
df.plot.scatter(y='pelvic_incidence', x='class')
df.plot.scatter(y='pelvic_tilt', x='class')
df.plot.scatter(y='lumbar_lordosis_angle', x='class')
df.plot.scatter(y='sacral_slope', x='class')
df.plot.scatter(y='pelvic_radius', x='class')
# Out:
# <Axes: xlabel='class', ylabel='pelvic_radius'>

# %% [markdown]
# ### Visualizing multiple variables
#
# As the previous steps demonstrate, visualizations can be very powerful. Sometimes, you will want to analyze multiple data points. You can do this by using *groupby*.
#
# Plotting out the features for both *Abnormal* and *Normal* values side by side might help you observe any other differences.

# %%
df.groupby('class').boxplot(fontsize=20,rot=90,figsize=(20,10),patch_artist=True)
# Out:
# 0         Axes(0.1,0.15;0.363636x0.75)
# 1    Axes(0.536364,0.15;0.363636x0.75)
# dtype: object

# %% [markdown]
# Using the **corr** function, you can create a correlation matrix for the entire dataset.

# %%
corr_matrix = df.corr()
corr_matrix["class"].sort_values(ascending=False)
# Out:
# class                       1.000000
# degree_spondylolisthesis    0.443687
# pelvic_incidence            0.353336
# pelvic_tilt                 0.326063
# lumbar_lordosis_angle       0.312484
# sacral_slope                0.210602
# pelvic_radius              -0.309857
# Name: class, dtype: float64

# %% [markdown]
# You can also plot out this data.

# %%
pd.plotting.scatter_matrix(df,figsize=(12,12))
plt.show()

# %% [markdown]
# By using **seaborn**, you can visualize the correlation as a *heatmap*.

# %%
# !pip install seaborn
# Out:
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from seaborn) (2.2.6)
# Requirement already satisfied: pandas>=1.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from seaborn) (2.3.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from seaborn) (3.10.9)
# Requirement already satisfied: contourpy>=1.0.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.65.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.5.1)
# Requirement already satisfied: packaging>=20.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.2)
# Requirement already satisfied: pillow>=8 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.3.0)
# Requirement already satisfied: pyparsing>=3 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from pandas>=1.2->seaborn) (2026.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from pandas>=1.2->seaborn) (2026.3)
# Requirement already satisfied: six>=1.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2

# %%
import seaborn as sns
# Plot figsize
fig, ax = plt.subplots(figsize=(10, 10))
# Generate Color Map
# colormap = sns.diverging_palette(220, 10, as_cmap=True)
colormap = sns.color_palette("BrBG", 10)
# Generate Heat Map, allow annotations and place floats in map
sns.heatmap(corr_matrix, cmap=colormap, annot=True, fmt=".2f")
#ax.set_yticklabels(column_names);
plt.show()

# %% [markdown]
# **Challenge task:** Find other data from the UCI Machine Learning Repository.  Using the previous code for reference, go explore!

# %% [markdown]
# Aqui nos dieron la opcion de usar cualquier tipo de dato para repetir el proceso anterior con los neuvos datos, o la nueva base de datos mejor dicho, decidi ir con lo simple y use el de "iris", facil de los datasets mas conocidos para este tipo de ejercicios, sobre todo en R. Iris contiene almacenado en su datasets 150 tipos de flores distintas, estas se organizan por tres tipos de flores (setosa, versicolor y virginica) y a su vez, se tienen en cuenta 4 tipos de atributos (largo/ancho de pétalo y sépalo), este dataset tiene la fama que tiene por lo ligero que es y no poseer datos nulos, lo que facilita su uso para experimentar.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data'
columnas = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'class']

df = pd.read_csv(url, header=None, names=columnas)
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width        class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df.drop('class', axis=1).plot(figsize=(10,6))
plt.show()

# %%
df.drop('class', axis=1).plot.density(subplots=True, figsize=(10,8), layout=(2,2))
plt.tight_layout()
plt.show()

# %%
df.drop('class', axis=1).plot.box(figsize=(8,6))
plt.show()

# %%
class_mapper = {'Iris-setosa': 0, 'Iris-versicolor': 1, 'Iris-virginica': 2}
df['class_num'] = df['class'].replace(class_mapper)
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width        class  \
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa
#
#    class_num
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0

# %%
fig, axes = plt.subplots(2, 2, figsize=(12,8))
axes = axes.flatten()

for i, col in enumerate(['sepal_length', 'sepal_width', 'petal_length', 'petal_width']):
    df.plot.scatter(y=col, x='class_num', ax=axes[i])

plt.tight_layout()
plt.show()

# %%
sns.heatmap(df.drop('class', axis=1).corr(), annot=True, cmap='coolwarm')
plt.show()

# %% [markdown]
# # Congratulations!
#
# You have completed this lab, and you can now end the lab by following the lab guide instructions.
